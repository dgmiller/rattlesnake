# %%
# import statements
import pandas as pd
import numpy as np
import scipy as sp
from matplotlib import pyplot as plt
from matplotlib import style
import sklearn
# %matplotlib inline
style.use('ggplot')

# %%
""" #read in csv
dataframe = pd.read_csv('Data/skcancerdata.csv')

dataframe.drop('Unnamed: 0', axis=1, inplace=True)
dataframe.drop('Result', axis=1, inplace=True)
dataframe.drop('Result measure', axis=1, inplace=True)
dataframe.drop('Normal Range', axis=1, inplace=True)
dataframe.drop('Status', axis=1, inplace=True)
dataframe.drop('Data type', axis=1, inplace=True)

#print(dataframe)
# remove: Unnamed, Result, Result measure, Normal Range
# change: Status from LL,L,N,H to -2,-1,0,1
"""
# Out:
# " #read in csv\ndataframe = pd.read_csv('Data/skcancerdata.csv')\n\ndataframe.drop('Unnamed: 0', axis=1, inplace=True)\ndataframe.drop('Result', axis=1, inplace=True)\ndataframe.drop('Result measure', axis=1, inplace=True)\ndataframe.drop('Normal Range', axis=1, inplace=True)\ndataframe.drop('Status', axis=1, inplace=True)\ndataframe.drop('Data type', axis=1, inplace=True)\n\n#print(dataframe)\n# remove: Unnamed, Result, Result measure, Normal Range\n# change: Status from LL,L,N,H to -2,-1,0,1\n"

# %%
cancerDF = pd.read_csv('skclean.csv', index_col=0)
print(cancerDF)
# Out:
#            Date   Component  Result    Low   High
# 0     9/17/2014      Weight   104.4    NaN    NaN
# 1     9/26/2014      Weight   104.8  104.4  104.4
# 2    11/12/2014      Weight    94.4  104.8  104.8
# 3      1/9/2015      Weight    89.6   94.4   94.4
# 4     1/20/2015      Weight    90.6   89.6   89.6
# 5     1/27/2015      Weight    86.8   90.6   90.6
# 6      2/3/2015      Weight    87.4   86.8   86.8
# 7     2/17/2015      Weight    88.0   87.4   87.4
# 8      3/3/2015      Weight    85.0   88.0   88.0
# 9     3/17/2015      Weight    86.2   85.0   85.0
# 10    3/31/2015      Weight    84.4   86.2   86.2
# 11    4/28/2015      Weight    90.2   89.0   89.0
# 12    5/12/2015      Weight    92.4   90.2   90.2
# 13    5/26/2015      Weight    97.6   92.4   92.4
# 14     6/9/2015      Weight    97.0   97.6   97.6
# 15    6/23/2015      Weight    99.2   99.2   99.2
# 16    8/11/2015      Weight   106.2   99.2   99.2
# 17   11/13/2015      Weight   115.6  106.2  106.2
# ...

# %%
ax = otherDF.plot(figsize=(24,6), kind='scatter', x='i', y='Low', color='Black')
otherDF.plot(kind='scatter', x='i', y='High', color='Black', ax=ax)
otherDF.plot(kind='scatter', x='i', y='Result', color='Red', ax=ax)
